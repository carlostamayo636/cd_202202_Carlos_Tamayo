# %% [markdown]
# <a href="https://colab.research.google.com/github/carlostamayo636/cd_202202_Carlos_Tamayo/blob/main/Taller9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import statsmodels.api as sm

ruta = 'https://raw.githubusercontent.com/adiacla/bigdata/master/titanic.csv'
df = pd.read_csv(ruta)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df = df.drop('Cabin', axis=1)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df = df.dropna()
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
x = df.iloc[:,[5,6,7]]
y = df.Survived
logit_model = sm.Logit(y,x)
result = logit_model.fit()
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.665234
#          Iterations 4
#                            Logit Regression Results
# ...
# Dep. Variable:               Survived   No. Observations:                  712
# Model:                          Logit   Df Residuals:                      709
# Method:                           MLE   Df Model:                            2
# Date:                Sat, 05 Nov 2022   Pseudo R-squ.:                 0.01416
# Time:                        22:35:27   Log-Likelihood:                -473.65
# converged:                       True   LL-Null:                       -480.45
# Covariance Type:            nonrobust   LLR p-value:                  0.001108
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Age           -0.0135      0.003     -5.273      0.000      -0.019      -0.008
# ...

# %%
# 1 para hombres, 0 para mujeres
df = pd.get_dummies(df, columns = ["Sex"], drop_first = True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name   Age  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris  22.0      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                               Heikkinen, Miss. Laina  26.0      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                             Allen, Mr. William Henry  35.0      0      0
# ..                                                 ...   ...    ...    ...
# ...

# %%
x = df.iloc[:,[4,5,6,10]]
y = df.Survived
logit_model = sm.Logit(y,x)
result = logit_model.fit()
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.548462
#          Iterations 5
#                            Logit Regression Results
# ...
# Dep. Variable:               Survived   No. Observations:                  712
# Model:                          Logit   Df Residuals:                      708
# Method:                           MLE   Df Model:                            3
# Date:                Sat, 05 Nov 2022   Pseudo R-squ.:                  0.1872
# Time:                        22:35:27   Log-Likelihood:                -390.51
# converged:                       True   LL-Null:                       -480.45
# Covariance Type:            nonrobust   LLR p-value:                 9.300e-39
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Age            0.0208      0.004      5.198      0.000       0.013       0.029
# ...

# %%
hashEmbarked={
    1:'S', 
    2:'C',
    3:'Q'
}

df['EmbarkedNum'] = df['Embarked'].replace(
  # Reemplaza cada valor por el valor en la segunda lista en el mismo índice del match.
  hashEmbarked.values(), # Lista de Strings
  hashEmbarked.keys() # Lista de Números
)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name   Age  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris  22.0      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                               Heikkinen, Miss. Laina  26.0      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                             Allen, Mr. William Henry  35.0      0      0
# ..                                                 ...   ...    ...    ...
# ...

# %%
x = df.iloc[:,[4,5,6,10,11]]
y = df.Survived
logit_model = sm.Logit(y,x)
result = logit_model.fit()
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.527540
#          Iterations 5
#                            Logit Regression Results
# ...
# Dep. Variable:               Survived   No. Observations:                  712
# Model:                          Logit   Df Residuals:                      707
# Method:                           MLE   Df Model:                            4
# Date:                Sat, 05 Nov 2022   Pseudo R-squ.:                  0.2182
# Time:                        22:35:27   Log-Likelihood:                -375.61
# converged:                       True   LL-Null:                       -480.45
# Covariance Type:            nonrobust   LLR p-value:                 3.103e-44
# ...
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Age             0.0027      0.005      0.517      0.605      -0.008       0.013
# ...

# %% [markdown]
# Segunda parte del taller

# %%
from sklearn.model_selection import train_test_split 

train, test = train_test_split(df, test_size = 0.20)

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 243          244         0       3
# 282          283         0       3
# 644          645         1       3
# 452          453         0       1
# 142          143         1       3
# ..           ...       ...     ...
# 616          617         0       3
# 112          113         0       3
# 148          149         0       2
# 582          583         0       2
# 758          759         0       3
#
#                                                   Name    Age  SibSp  Parch  \
# 243                      Maenpaa, Mr. Matti Alexanteri  22.00      0      0
# 282                          de Pelsmaeker, Mr. Alfons  16.00      0      0
# 644                             Baclini, Miss. Eugenie   0.75      2      1
# 452                    Foreman, Mr. Benjamin Laventall  30.00      0      0
# 142  Hakkarainen, Mrs. Pekka Pietari (Elin Matilda ...  24.00      1      0
# ..                                                 ...    ...    ...    ...
# ...

# %%
x = train.iloc[:,[4,5,6]]
y = train.Survived
logit_model = sm.Logit(y,x)
result = logit_model.fit()

resum = result.summary()

print(resum)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.655196
#          Iterations 4
#                            Logit Regression Results
# ...
# Dep. Variable:               Survived   No. Observations:                  569
# Model:                          Logit   Df Residuals:                      566
# Method:                           MLE   Df Model:                            2
# Date:                Sat, 05 Nov 2022   Pseudo R-squ.:                 0.01178
# Time:                        22:38:03   Log-Likelihood:                -372.81
# converged:                       True   LL-Null:                       -377.25
# Covariance Type:            nonrobust   LLR p-value:                   0.01176
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Age           -0.0166      0.003     -5.704      0.000      -0.022      -0.011
# ...

# %% [markdown]
# edad*coefEdad + sib*coefSibSp + parch*coefParch

# %%
import statsmodels.api as sm

results_summary = resum

resultsHTML = results_summary.tables[1].as_html()

table = pd.read_html(resultsHTML, header=0, index_col=0)[0]

# %%
ageCoef = table['coef'].values[0]
SibSpCoef = table['coef'].values[1]
ParchCoef = table['coef'].values[2]

# %%
import math

# %%
truePositive = 0
falseNegative = 0
falsePositive = 0
trueNegative = 0

probList = []

for i in test.index:

  valor = (ageCoef*test['Age'][i]) + (SibSpCoef*test['SibSp'][i]) + (ParchCoef*test['Parch'][i])

  prob = 1 / (1 + math.e ** (-1 * valor))

  probList.append(prob)

  if prob<0.5:
    trunc = 0
  else:
    trunc = 1

  trueVal = test['Survived'][i]

  if(trueVal == 1 and trunc == 1):
    truePositive += 1
  elif(trueVal == 1 and trunc == 0):
    falseNegative += 1
  elif(trueVal == 0 and trunc == 1):
    falsePositive += 1
  elif(trueVal == 0 and trunc == 0):
    trueNegative += 1

print("Verdadero Positivo: "+ str(truePositive))
print("Falso Negativo: " + str(falseNegative))
print("Falso Positivo: " + str(falsePositive))
print("Verdadero Negativo: " + str(trueNegative))

print(probList)
# Out:
# Verdadero Positivo: 12
# Falso Negativo: 61
# Falso Positivo: 4
# Verdadero Negativo: 66
# ...

# %%
p = truePositive / (truePositive + falsePositive)
print("Precision: " + str(p*100))
# Out:
# Precision: 75.0

# %%
r = truePositive / (falseNegative + truePositive)
print("Exhaustividad: " + str(r*100))
# Out:
# Exhaustividad: 16.43835616438356

# %% [markdown]
# *
# Incluyendo Sexo
# *

# %%
x = train.iloc[:,[4,5,6,10]]
y = train.Survived
logit_model = sm.Logit(y,x)
result = logit_model.fit()
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.524256
#          Iterations 6
#                            Logit Regression Results
# ...
# Dep. Variable:               Survived   No. Observations:                  569
# Model:                          Logit   Df Residuals:                      565
# Method:                           MLE   Df Model:                            3
# Date:                Sat, 05 Nov 2022   Pseudo R-squ.:                  0.2093
# Time:                        22:38:29   Log-Likelihood:                -298.30
# converged:                       True   LL-Null:                       -377.25
# Covariance Type:            nonrobust   LLR p-value:                 5.213e-34
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Age            0.0210      0.005      4.577      0.000       0.012       0.030
# ...

# %%
import statsmodels.api as sm

results_summary = result.summary()

resultsHTML = results_summary.tables[1].as_html()

table = pd.read_html(resultsHTML, header=0, index_col=0)[0]

# %%
ageCoef = table['coef'].values[0]
SibSpCoef = table['coef'].values[1]
ParchCoef = table['coef'].values[2]
SexMaleCoef = table['coef'].values[3]

# %%
truePositive = 0
falseNegative = 0
falsePositive = 0
trueNegative = 0

probList = []

for i in test.index:

  valor = (ageCoef*test['Age'][i]) + (SibSpCoef*test['SibSp'][i]) + (ParchCoef*test['Parch'][i]) + (SexMaleCoef*test['Parch'][i])

  prob = 1 / (1 + math.e ** (-1 * valor))

  probList.append(prob)

  if prob<0.5:
    trunc = 0
  else:
    trunc = 1

  trueVal = test['Survived'][i]

  if(trueVal == 1 and trunc == 1):
    truePositive += 1
  elif(trueVal == 1 and trunc == 0):
    falseNegative += 1
  elif(trueVal == 0 and trunc == 1):
    falsePositive += 1
  elif(trueVal == 0 and trunc == 0):
    trueNegative += 1

print("Verdadero Positivo: "+ str(truePositive))
print("Falso Negativo: " + str(falseNegative))
print("Falso Positivo: " + str(falsePositive))
print("Verdadero Negativo: " + str(trueNegative))

print(probList)
# Out:
# Verdadero Positivo: 41
# Falso Negativo: 32
# Falso Positivo: 50
# Verdadero Negativo: 20
# ...

# %%
p = truePositive / (truePositive + falsePositive)
print("Precision: " + str(p*100))
# Out:
# Precision: 45.05494505494506

# %%
r = truePositive / (falseNegative + truePositive)
print("Exhaustividad: " + str(r*100))
# Out:
# Exhaustividad: 56.16438356164384
